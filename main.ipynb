# %%
import streamlit as st
import joblib
from datetime import datetime

# Page Configuration
st.set_page_config(page_title="Fetus Prediction App", page_icon="👶", layout="wide")

# Load the model
@st.cache_resource
def load_model():
    with open('rf_classifier.pkl', 'rb') as file:
        return joblib.load(file)

rf_classifier = load_model()

def main():
    st.title("Fetus Prediction App")
    
    # Create columns for layout
    col1, col2 = st.columns(2)
    
    # Column 1: Personal and Pregnancy Information
    with col1:
        # 1. Mother's Age
        usia_ibu_value = st.number_input("1. Usia Ibu:", min_value=10, max_value=50, value=25)
        
        # 2. Pregnancy Age
        usia_kandungan_value = st.number_input("2. Usia Kandungan:", min_value=1, max_value=40, value=10)
        
        # 3. Blood Type
        golongan_darah = st.radio("3. Golongan Darah", 
                                  ["A", "AB", "B", "O", "Tidak Tau"], 
                                  horizontal=True)
        
        # 4. Rhesus
        rhesus = st.radio("4. Rhesus", 
                          ["Positif (+)", "Negatif (-)", "Tidak Tau"], 
                          horizontal=True)
        
        # 5. Pregnancy Number
        hamil_ke_brp = st.radio("5. Hamil ke Berapa", 
                                [1, 2, 3, 4, "5 atau lebih"], 
                                horizontal=True)
    
    # Column 2: Medical and Lifestyle Information
    with col2:
        # 6. Caesar History
        riwayat_caesar = st.radio("6. Jumlah Riwayat Caesar", 
                                  [0, 1, 2, 3, "4 atau lebih"], 
                                  horizontal=True)
        
        # 7. Miscarriage History
        jumlah_keguguran = st.radio("7. Jumlah Keguguran", 
                                    [0, 1, 2, "3 atau lebih"], 
                                    horizontal=True)
        
        # 8. Desired Pregnancy
        kehamilan_diinginkan = st.radio("8. Apakah Kehamilan Ini Diinginkan?", 
                                        ["Ya", "Tidak"], 
                                        horizontal=True)
        
        # 9. Alcohol Use
        alkohol = st.radio("9. Apakah Anda Pengguna Alkohol?", 
                           ["Ya", "Tidak"], 
                           horizontal=True)
        
        # 10. Smoking
        rokok = st.radio("10. Apakah Anda Perokok?", 
                         ["Ya", "Tidak"], 
                         horizontal=True)
    
    # Next Row
    col3, col4 = st.columns(2)
    
    with col3:
        # 11. Drug Use
        narkoba = st.radio("11. Apakah Anda Pengguna Narkoba?", 
                           ["Ya", "Tidak"], 
                           horizontal=True)
        
        # 12. Pollution Exposure
        polusi = st.radio("12. Apakah Anda Sering Terpapar Polusi?", 
                          ["Ya", "Tidak"], 
                          horizontal=True)
        
        # 13. Postpartum Bleeding History
        riwayat_pendarahan = st.radio("13. Apakah Anda Memiliki Riwayat Pendarahan Pasca Lahir?", 
                                      ["Ya", "Tidak"], 
                                      horizontal=True)
        
        # 14. Bleeding During Pregnancy
        pedarahan_ketika = st.radio("14. Apakah Anda Pernah Mengalami Pendarahan Ketika Hamil?", 
                                    ["Ya", "Tidak"], 
                                    horizontal=True)
    
    with col4:
        # 15. Gadget Use
        gadget = st.radio("15. Apakah Anda Sering Menggunakan Gadget?", 
                          ["Ya", "Tidak"], 
                          horizontal=True)
        
        # 16. Congenital Abnormality History
        riwayat_kelainan = st.radio("16. Apakah Anda Memiliki Riwayat Kelainan Bawaan?", 
                                    ["Ya", "Tidak"], 
                                    horizontal=True)
        
        # 17. Allergy History
        riwayat_alergi = st.radio("17. Apakah Anda Memiliki Riwayat Alergi?", 
                                  ["Ya", "Tidak"], 
                                  horizontal=True)
        
        # 18. Previous Caesar
        pernah_caesar = st.radio("18. Apakah Anda Pernah Operasi Caesar?", 
                                 ["Ya", "Tidak"], 
                                 horizontal=True)
    
    # Medical History Sections
    col5, col6 = st.columns(2)
    
    with col5:
        # 19. Medical History
        st.write("19. Riwayat Penyakit")
        riwayat_penyakit = st.multiselect("", 
                                          ["Tidak Ada", "Diabetes", "Anemia", "Hipertensi", 
                                           "Paru-Paru", "Ginjal", "Preeklampsi", "Lainnya"],
                                          key="medical_history_multiselect")
        
        if "Lainnya" in riwayat_penyakit:
            riwayat_penyakit_lainnya = st.text_input("Sebutkan Riwayat Penyakit Lainnya", key="medical_history_text")
        else:
            riwayat_penyakit_lainnya = ""
    
    with col6:
        # 20. Hereditary Diseases
        st.write("20. Penyakit Turunan")
        penyakit_turunan = st.multiselect("", 
                                          ["Tidak Ada", "Diabetes", "Anemia", "Hipertensi", 
                                           "Paru-Paru", "Ginjal", "Preeklampsi", "Lainnya"],
                                          key="hereditary_diseases_multiselect")
        
        if "Lainnya" in penyakit_turunan:
            penyakit_turunan_lainnya = st.text_input("Sebutkan Penyakit Turunan Lainnya", key="hereditary_diseases_text")
        else:
            penyakit_turunan_lainnya = ""
    
    # Additional Information
    col7, col8 = st.columns(2)
    
    with col7:
        # 21. Midwife Information
        nama_bidan = st.text_input("21. Info Dari Bidan:")
    
    with col8:
        # 22. Number of Deliveries
        jumlah_persalinan = st.radio("22. Jumlah Persalinan", 
                                     [0, 1, 2, 3, "4 atau lebih"], 
                                     horizontal=True)
    
    # Prediction Button
    if st.button("Prediksi"):
        # Data Preprocessing
        # <Preprocessing logic here>
        # ...
        
        # Prediction
        prediction = rf_classifier.predict([[...]])
        
        prediction = 'Tinggi' if prediction == 0 else ('Normal' if prediction == 1 else 'Rendah')
        
        # Display Prediction
        st.success(f"Janin beresiko: {prediction}")

if __name__ == "__main__":
    main()
# Out:
# 2024-11-30 18:58:46.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.833 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-11-30 18:58:46.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.845 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-11-30 18:58:46.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-30 18:58:46.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
